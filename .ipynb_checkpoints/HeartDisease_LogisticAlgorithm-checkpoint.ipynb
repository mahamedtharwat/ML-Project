# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib as plt

# %%
df = pd.read_csv("Heart_Data_after_preprocessing.csv")

# %%
x = df.iloc[:,2:]
y= df.iloc[:,1:2]
display(x)
display(y)
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0             3.0          30.0
# 1       20.34        0                0       1             0.0           0.0
# 2       26.58        1                0       0            20.0          30.0
# 3       24.21        0                0       0             0.0           0.0
# 4       23.71        0                0       0            28.0           0.0
# ...       ...      ...              ...     ...             ...           ...
# 319790  27.41        1                0       0             7.0           0.0
# 319791  29.84        1                0       0             0.0           0.0
# 319792  24.24        0                0       0             0.0           0.0
# 319793  32.81        0                0       0             0.0           0.0
# 319794  46.56        0                0       0             0.0           0.0
#
#         DiffWalking  Sex  AgeCategory  Diabetic  ...  SkinCancer  Race_Asian  \
# 0                 0    0            7         2  ...           1       False
# 1                 0    0           12         0  ...           0       False
# 2                 0    1            9         2  ...           0       False
# 3                 0    0           11         0  ...           1       False
# 4                 1    0            4         0  ...           0       False
# ...             ...  ...          ...       ...  ...         ...         ...
# 319790            1    1            8         2  ...           0       False
# 319791            0    1            3         0  ...           0       False
# 319792            0    0            5         0  ...           0       False
# 319793            0    0            1         0  ...           0       False
# 319794            0    0           12         0  ...           0       False
#
#         Race_Black  Race_Hispanic  Race_Other  Race_White  GenHealth_Fair  \
# 0            False          False       False        True           False
# 1            False          False       False        True           False
# 2            False          False       False        True            True
# 3            False          False       False        True           False
# 4            False          False       False        True           False
# ...            ...            ...         ...         ...             ...
# 319790       False           True       False       False            True
# 319791       False           True       False       False           False
# 319792       False           True       False       False           False
# 319793       False           True       False       False           False
# 319794       False           True       False       False           False
#
#         GenHealth_Good  GenHealth_Poor  GenHealth_Very good
# 0                False           False                 True
# 1                False           False                 True
# 2                False           False                False
# 3                 True           False                False
# 4                False           False                 True
# ...                ...             ...                  ...
# 319790           False           False                False
# 319791           False           False                 True
# 319792            True           False                False
# 319793            True           False                False
# 319794            True           False                False
#
# [319795 rows x 24 columns]
#         HeartDisease
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 319790             1
# 319791             0
# 319792             0
# 319793             0
# 319794             0
#
# [319795 rows x 1 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=0)

# %%
model = LogisticRegression(random_state=0)
model.fit(x_train,y_train)
# Out:
# c:\Users\ELBOSTAN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\ELBOSTAN\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
train_score = model.score(x_train,y_train)
print(f'model Score/Performance on training DataSet: {round((train_score*100),2)}')
# Out:
# model Score/Performance on training DataSet: 91.55

# %%
test_score = model.score(x_test,y_test)
print(f'model Score/Performance on Testing DataSet: {round((test_score*100),2)}')
# Out:
# model Score/Performance on Testing DataSet: 91.56

# %%
y_pre = model.predict(x_test)
print(y_pre)
# Out:
# [0 0 0 ... 0 0 0]
