# %%
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv(r"C:\Users\Moham\OneDrive\Desktop\ProjectML\heart_2020.csv")
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.shape
# Out:
# (319795, 18)

# %%
df.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
df["Diabetic"] = df["Diabetic"].replace("No, borderline diabetes" , "No")
df
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               3
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
df["Race"].unique()
# Out:
# array(['White', 'Black', 'Asian', 'American Indian/Alaskan Native',
#        'Other', 'Hispanic'], dtype=object)

# %%
df[df['Smoking'].str.contains('No')]  # human not smoking
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 1                No  20.34      No              No    Yes             0.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# 6                No  21.63      No              No     No            15.0
# 8                No  26.45      No              No     No             0.0
# ...             ...    ...     ...             ...    ...             ...
# 319788           No  23.38      No              No     No             0.0
# 319789           No  22.22      No              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
le = LabelEncoder()    # numeric data

# %%
df["HeartDisease"] = le.fit_transform(df["HeartDisease"])
df
# Out:
#         HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                  0  16.60     Yes              No     No             3.0
# 1                  0  20.34      No              No    Yes             0.0
# 2                  0  26.58     Yes              No     No            20.0
# 3                  0  24.21      No              No     No             0.0
# 4                  0  23.71      No              No     No            28.0
# ...              ...    ...     ...             ...    ...             ...
# 319790             1  27.41     Yes              No     No             7.0
# 319791             0  29.84     Yes              No     No             0.0
# 319792             0  24.24      No              No     No             0.0
# 319793             0  32.81      No              No     No             0.0
# 319794             0  46.56      No              No     No             0.0
#
# ...

# %%
cols=["Smoking", "AlcoholDrinking", "Stroke", "PhysicalHealth", "MentalHealth", "DiffWalking", "Sex",
       "AgeCategory", "Diabetic", "PhysicalActivity", "SleepTime", "Asthma", "KidneyDisease","SkinCancer"]

for col in cols:
    df[col]=le.fit_transform(df[col])

# %%
df.dtypes
# Out:
# HeartDisease          int32
# BMI                 float64
# Smoking               int32
# AlcoholDrinking       int32
# Stroke                int32
# PhysicalHealth        int64
# MentalHealth          int64
# DiffWalking           int32
# Sex                   int32
# AgeCategory           int32
# Race                 object
# Diabetic              int32
# PhysicalActivity      int32
# GenHealth            object
# SleepTime             int64
# Asthma                int32
# KidneyDisease         int32
# SkinCancer            int32
# dtype: object

# %%
df
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0               3
# 1                  0  20.34        0                0       1               0
# 2                  0  26.58        1                0       0              20
# 3                  0  24.21        0                0       0               0
# 4                  0  23.71        0                0       0              28
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0               7
# 319791             0  29.84        1                0       0               0
# 319792             0  24.24        0                0       0               0
# 319793             0  32.81        0                0       0               0
# 319794             0  46.56        0                0       0               0
#
# ...

# %%
df = pd.get_dummies(df,drop_first=True) # Hot Encoding
df
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        1                0       0               3
# 1                  0  20.34        0                0       1               0
# 2                  0  26.58        1                0       0              20
# 3                  0  24.21        0                0       0               0
# 4                  0  23.71        0                0       0              28
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        1                0       0               7
# 319791             0  29.84        1                0       0               0
# 319792             0  24.24        0                0       0               0
# 319793             0  32.81        0                0       0               0
# 319794             0  46.56        0                0       0               0
#
# ...

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, 1:].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
cl = KNeighborsClassifier(n_neighbors=100) 
cl.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
y_pred = cl.predict(x_test)

# %%
len(y_pred)
# Out:
# 63959

# %%
from sklearn import metrics

# %%
acc = metrics.accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.5826388780312388
